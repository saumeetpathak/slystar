# %% [markdown]
# # <font color=''>1.Import the "Telecom_Customer_Churn.csv" dataset</font>

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv(r"C:\Users\darsh\OneDrive\Documents\Desktop\CL_1 Prt\Datasets\Telco-Customer-Churn.csv")
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges Churn
# 0           Electronic check          29.85         29.85    No
# 1               Mailed check          56.95        1889.5    No
# 2               Mailed check          53.85        108.15   Yes
# 3  Bank transfer (automatic)          42.30       1840.75    No
# 4           Electronic check          70.70        151.65   Yes
#
# [5 rows x 21 columns]

# %% [markdown]
# # <font color=''>2. Explore the dataset to understand its structure and content </font>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
#  16  PaperlessBilling  7043 non-null   object
#  17  PaymentMethod     7043 non-null   object
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7043 non-null   object
#  20  Churn             7043 non-null   object
# dtypes: float64(1), int64(2), object(18)
# memory usage: 1.1+ MB

# %%
data.shape
# Out:
# (7043, 21)

# %%
data.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %% [markdown]
# # 3.Remove any duplicate records from the dataset

# %%
data[data.duplicated(subset=['customerID'])].T
# Out:
# Empty DataFrame
# Columns: []
# Index: [customerID, gender, SeniorCitizen, Partner, Dependents, tenure, PhoneService, MultipleLines, InternetService, OnlineSecurity, OnlineBackup, DeviceProtection, TechSupport, StreamingTV, StreamingMovies, Contract, PaperlessBilling, PaymentMethod, MonthlyCharges, TotalCharges, Churn]

# %%
data = data.drop_duplicates(subset=['customerID'])

# %%
data.shape
# Out:
# (7043, 21)

# %% [markdown]
# # 4.Check for inconsistent data, such as inconsistent formatting or spelling variations, and standardize it

# %%
data['gender'].value_counts()
# Out:
# gender
# Male      3555
# Female    3488
# Name: count, dtype: int64

# %%
data['gender'] = data['gender'].replace({'F':'Female','M ':'Male'})

# %%
data.gender.value_counts()
# Out:
# gender
# Male      3555
# Female    3488
# Name: count, dtype: int64

# %% [markdown]
# # 5.Handle missing values in the dataset, deciding on an appropriate strategy

# %%
data.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
categorical_cols = ['gender','Partner','Dependents','PhoneService','MultipleLines','InternetService','OnlineSecurity','OnlineBackup','DeviceProtection','TechSupport','StreamingTV','Contract','StreamingMovies','PaymentMethod','Churn']
numercial_cols = ['MonthlyCharges','tenure','TotalCharges']

for col in categorical_cols:
    data[col].fillna(data[col].mode()[0], inplace=True)

for col in numercial_cols:
    data[col] = pd.to_numeric(data[col], errors='coerce')  # Convert to numeric
    data[col].fillna(data[col].mean(), inplace=True)
# Out:
# C:\Users\darsh\AppData\Local\Temp\ipykernel_17904\3693306885.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[col].fillna(data[col].mode()[0], inplace=True)
# C:\Users\darsh\AppData\Local\Temp\ipykernel_17904\3693306885.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[col].fillna(data[col].mean(), inplace=True)

# %%
data.isna().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [markdown]
# # 6.Convert columns to the correct data types as needed.

# %%
data.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                object
# dtype: object

# %%
data[['tenure','MonthlyCharges','TotalCharges']] = data[['tenure','MonthlyCharges','TotalCharges']].astype('int64')

# %%
data.dtypes
# Out:
# customerID          object
# gender              object
# SeniorCitizen        int64
# Partner             object
# Dependents          object
# tenure               int64
# PhoneService        object
# MultipleLines       object
# InternetService     object
# OnlineSecurity      object
# OnlineBackup        object
# DeviceProtection    object
# TechSupport         object
# StreamingTV         object
# StreamingMovies     object
# Contract            object
# PaperlessBilling    object
# PaymentMethod       object
# MonthlyCharges       int64
# TotalCharges         int64
# Churn               object
# dtype: object

# %% [markdown]
# # 7. Identify and handle outliers in the data.

# %%
# Detecting outliers
outliers = data[(data["MonthlyCharges"] > 3.5 * data["MonthlyCharges"].std()) | (data["MonthlyCharges"] < -3.5 * data["MonthlyCharges"].std())]
outliers
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 15    3655-SNQYZ  Female              0     Yes        Yes      69
# 17    9959-WOFKT    Male              0      No        Yes      71
# 38    5380-WJKOV    Male              0      No         No      34
# 57    5067-XJQFU    Male              1     Yes        Yes      66
# 59    5954-BDFSG  Female              0      No         No      72
# ...          ...     ...            ...     ...        ...     ...
# 6913  8213-TAZPM  Female              0     Yes        Yes      69
# 6935  4616-ULAOA  Female              0     Yes        Yes      65
# 6952  6394-MFYNG  Female              0      No         No      48
# 6972  6664-FPDAC  Female              1      No         No      56
# 6987  5981-ZVXOT  Female              1      No         No      35
#
#      PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 15            Yes           Yes     Fiber optic            Yes  ...
# 17            Yes           Yes     Fiber optic            Yes  ...
# 38            Yes           Yes     Fiber optic             No  ...
# 57            Yes           Yes     Fiber optic             No  ...
# 59            Yes           Yes     Fiber optic             No  ...
# ...           ...           ...             ...            ...  ...
# 6913          Yes           Yes     Fiber optic             No  ...
# 6935          Yes           Yes     Fiber optic             No  ...
# 6952          Yes           Yes     Fiber optic             No  ...
# 6972          Yes           Yes     Fiber optic             No  ...
# 6987          Yes           Yes     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 15                Yes         Yes         Yes             Yes        Two year
# 17                Yes          No         Yes             Yes        Two year
# 38                Yes          No         Yes             Yes  Month-to-month
# 57                Yes         Yes         Yes             Yes        One year
# 59                Yes         Yes         Yes             Yes        Two year
# ...               ...         ...         ...             ...             ...
# 6913              Yes         Yes         Yes             Yes        One year
# 6935              Yes         Yes         Yes             Yes        Two year
# 6952              Yes          No         Yes             Yes  Month-to-month
# 6972              Yes         Yes         Yes             Yes        One year
# 6987              Yes          No         Yes             Yes        One year
#
#      PaperlessBilling              PaymentMethod MonthlyCharges  TotalCharges  \
# 15                 No    Credit card (automatic)            113          7895
# 17                 No  Bank transfer (automatic)            106          7382
# 38                Yes           Electronic check            106          3549
# 57                Yes           Electronic check            108          7076
# 59                Yes    Credit card (automatic)            107          7853
# ...               ...                        ...            ...           ...
# 6913              Yes  Bank transfer (automatic)            108          7493
# 6935              Yes    Credit card (automatic)            110          7245
# 6952              Yes  Bank transfer (automatic)            107          5121
# 6972              Yes           Electronic check            111          6418
# 6987              Yes           Electronic check            108          3726
#
#       Churn
# 15       No
# 17       No
# 38      Yes
# 57       No
# 59       No
# ...     ...
# 6913     No
# 6935     No
# 6952    Yes
# 6972    Yes
# 6987     No
#
# [427 rows x 21 columns]

# %%
# Removed outliers
data = data[(data["MonthlyCharges"] < 3.5 * data["MonthlyCharges"].std()) & (data["MonthlyCharges"] > -3.5 * data["MonthlyCharges"].std())]

# %%
data.shape
# Out:
# (6616, 21)

# %% [markdown]
# # 8.Perform feature engineering, creating new features that may be relevant to predicting customer churn

# %%
data['early_churn'] = (data['tenure'] <= 12) & (data['Churn'] == 'Yes')

# %%
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... TechSupport  \
# 0  No phone service             DSL             No  ...          No
# 1                No             DSL            Yes  ...          No
# 2                No             DSL            Yes  ...          No
# 3  No phone service             DSL            Yes  ...         Yes
# 4                No     Fiber optic             No  ...          No
#
#   StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No              No  Month-to-month              Yes
# 1          No              No        One year               No
# 2          No              No  Month-to-month              Yes
# 3          No              No        One year               No
# 4          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges TotalCharges  Churn  early_churn
# 0           Electronic check             29           29     No        False
# 1               Mailed check             56         1889     No        False
# 2               Mailed check             53          108    Yes         True
# 3  Bank transfer (automatic)             42         1840     No        False
# 4           Electronic check             70          151    Yes         True
#
# [5 rows x 22 columns]

# %% [markdown]
# # 9. Normalize or scale the data if necessary

# %%
from sklearn.preprocessing import Normalizer as n

data[['MonthlyCharges','TotalCharges']] = n().fit_transform(data[['MonthlyCharges','TotalCharges']])

# %%
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... TechSupport  \
# 0  No phone service             DSL             No  ...          No
# 1                No             DSL            Yes  ...          No
# 2                No             DSL            Yes  ...          No
# 3  No phone service             DSL            Yes  ...         Yes
# 4                No     Fiber optic             No  ...          No
#
#   StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No              No  Month-to-month              Yes
# 1          No              No        One year               No
# 2          No              No  Month-to-month              Yes
# 3          No              No        One year               No
# 4          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges TotalCharges  Churn  early_churn
# 0           Electronic check       0.707107     0.707107     No        False
# 1               Mailed check       0.029632     0.999561     No        False
# 2               Mailed check       0.440551     0.897727    Yes         True
# 3  Bank transfer (automatic)       0.022820     0.999740     No        False
# 4           Electronic check       0.420582     0.907255    Yes         True
#
# [5 rows x 22 columns]

# %% [markdown]
# # 10.Split the dataset into training and testing sets for further analysis

# %%
from sklearn.model_selection import train_test_split

X = data.drop('Churn',axis=1)
y = data['Churn']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
X_train.shape
# Out:
# (4432, 21)

# %%
data.shape
# Out:
# (6616, 22)

# %% [markdown]
# # 11. Export the cleaned dataset for future analysis or modeling.

# %%
X_train.to_csv('Xtrain.csv')
X_test.to_csv('Xtest.csv')
